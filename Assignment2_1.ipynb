# %% [markdown]
# <a href="https://colab.research.google.com/github/venkateshnaramula/AI-ML_Batch_5-4/blob/main/Assignment2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## implementing BFS![bfs1.png](data:image/png;base64,...)
